# %% [markdown]
# **Primary structure features**

# %%
CUDA_VISIBLE_DEVICES=0,1 python extract_features4.py 
-–input_file=/home/pnunez/data/bert/sara/protein_subsequences.txt 
-–output_file=/home/pnunez/data/bert/sara/output_primary.txt 
-–vocab_file=/home/pnunez/data/bert/protein-vocab.txt 
-–bert_config_file=/home/pnunez/data/bert/bert_config.json 
-–init_checkpoint=/home/pnunez/data/bert/model2/model.ckpt-14000000 
--max_seq_length=30 
--layers=-1
-–batch_size=32

# %% [markdown]
# **Secondary structure features**

# %%
CUDA_VISIBLE_DEVICES=0,1 python extract_features4.py 
-–input_file=/home/pnunez/data/bert/sara/prediction_subsequences.txt 
-–output_file=/home/pnunez/data/bert/sara/output_secondary.txt 
-–vocab_file=/home/pnunez/data/bert/sara/secondary-vocab.txt 
-–bert_config_file=/home/pnunez/data/bert/sara/bert_config.json 
-–init_checkpoint=/home/pnunez/data/bert/sara/model.ckpt-500000 
--max_seq_length=30 
--layers=-1
-–batch_size=32
